# %% [markdown]
# # Some ground rules for the assignments:
#
# For all assignments (this one and any future assignment including the final project):
#
# * Do not download and save the data locally unless your data is very big (~TBs). I **do not** want to see you opening a local file for the data I gave you as an URL. Anything local is suspect: local files can't be trusted (they might be manipulated, changed, modified, tempered.) Refer to my lecture notes on how to pull data from an URL using `urlopen`.
#
# * All computations must be done locally within python. Nothing external: no manual input, no excel, no SQL, no java, etc.
#
# * All code has to be explained. Explain your reasoning and your choices. If you installed a third party library (including `numpy`, `scipy`, `pandas` etc), explain which part you import and what that function does etc.
#
# * Explain your code using a markdown cell. **Do not** use code comments starting with `#` to do your explanations.
#
# * Do not use `if __name__ == "__main__"`. EVER! If you are using that within jupyter, I am going to assume you found the solution on the internet and you cut/pasted without understanding what that peice of code did.

# %% [markdown]
# # Question 1
#
# Istanbul municipality has a open data service, and it provides detailed information about their services. For this question, use the data given at [this link](https://data.ibb.gov.tr/dataset/istanbul-sehir-hatlari-iskeleleri).
#
# 1. Understand what the data is for. Explain what it is, what it records, what pieces it has in broad strokes.
#
# 2. Data (among other things) contains geographical locations of Sea Stations ('Iskele') of Istanbul Deniz Isletmeleri boats operating in Istanbul.  Extract the locations of these stations as a pandas dataframe with 2 columns: latitudes and longitudes. The index of the dataframe has to be the station names.
#
# The data is in XML format. Do not use any external libraries other than numpy and pandas. Use `xmltodict` to convert it into a dictionary then extract the necessary parts.

# %%
from xmltodict import parse
from urllib.request import urlopen
import pandas as pd

# %% [markdown]
# ## Libraries
# 1. parse: use this library to parse our data in xml format and convert it to dictionary format.
# 2. pandas: use for dataframe process

# %%
with urlopen("https://data.ibb.gov.tr/dataset/b47b5391-bcca-4bb3-a575-8ece68901d5d/resource/bcbeff5d-14d7-4ec0-a211-4c4d3e96cfba/download/istanbul-ehir-hatlar-iskeleleri.kml") as url:
    raw = parse(url,encoding='utf-8')
raw = raw['kml']['Document']['Folder']['Folder']
data=pd.DataFrame(raw)

# %% [markdown]
# # create and analyze the data
# 1. We pull the data from the url and parse it into dictionary.
# 2. Then get the part we are working on from the raw data
# 3. Finally, we turn the data into a dataframe for better processing.

# %%
data
# Out:
#                 name open                                          Placemark  \
# 0   MERKEZ İSKELELER    1  [{'name': 'MALTEPE', 'LookAt': {'gx:TimeStamp'...
# 1   HALİÇ İSKELELERİ  NaN  [{'name': 'AYVANSARAY', 'LookAt': {'gx:TimeSpa...
# 2     ADA İSKELELERİ  NaN  [{'name': 'BURGAZADA', 'LookAt': {'gx:TimeStam...
# 3   BOĞAZ İSKELELERİ  NaN  [{'name': 'ANADOLU HİSARI', 'LookAt': {'gx:Tim...
# 4  ARABALI İSKELELER  NaN  [{'name': 'ÇUBUKLU ARABALI', 'Camera': {'gx:Ti...
#
#                                               LookAt  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {'longitude': '29.08634193274094', 'latitude':...
# 4                                                NaN
#
#                                                Style
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {'ListStyle': {'listItemType': 'check', 'bgCol...
# 4                                                NaN

# %% [markdown]
# When we examine the data, we see that the data divides the sea stations into 5 zones and shows the names and locations of the sea stations in these regions in the placemark area.

# %% [markdown]
# #  Placemarks

# %%
placemark=data['Placemark']
length =len(placemark)
df=pd.DataFrame({'a' : []})
for i in range(length):
    df2 = pd.DataFrame.from_dict(placemark[i])
    df=pd.concat([df, df2], ignore_index=True)
del df['a']

# %% [markdown]
# 1. we define an empty dataframe to gather all the placemarks together
# 2. Using for loop, we reach all the placemarks and combine with new dataframe.

# %%
df
# Out:
#                name                                             LookAt  \
# 0           MALTEPE  {'gx:TimeStamp': {'when': '2020-06-16'}, 'gx:V...
# 1          AHIRKAPI                                                NaN
# 2        BEŞİKTAŞ-1  {'gx:TimeStamp': {'when': '2017-06-14'}, 'gx:V...
# 3        BEŞİKTAŞ-2  {'gx:TimeStamp': {'when': '2014-07-10'}, 'gx:V...
# 4          BOSTANCI  {'gx:TimeStamp': {'when': '2017-06-14'}, 'gx:V...
# 5         EMİNÖNÜ-1                                                NaN
# 6         EMİNÖNÜ-2                                                NaN
# 7         EMİNÖNÜ-3                                                NaN
# 8         EMİNÖNÜ-4                                                NaN
# 9        HAYDARPAŞA                                                NaN
# 10          KABATAŞ                                                NaN
# 11        KADIKÖY-1                                                NaN
# 12        KADIKÖY-2                                                NaN
# 13          KARAKÖY                                                NaN
# 14        KARAKÖY-2  {'longitude': '28.97517820592657', 'latitude':...
# 15             MODA  {'gx:TimeStamp': {'when': '2018-03-30'}, 'gx:V...
# 16          ÜSKÜDAR  {'gx:TimeStamp': {'when': '2017-05-25'}, 'gx:V...
# 17       AYVANSARAY  {'gx:TimeSpan': {'begin': '2017-10-17T00:00:35...
# 18            BALAT  {'longitude': '28.9489827381236', 'latitude': ...
# 19    EMİNÖNÜ HALİÇ  {'gx:TimeStamp': {'when': '2017-05-25'}, 'gx:V...
# 20      EYÜP SULTAN  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 21            FENER  {'gx:TimeSpan': {'begin': '2017-10-17T00:00:35...
# 22           HASKÖY  {'longitude': '28.94926476460193', 'latitude':...
# 23        KASIMPAŞA  {'gx:TimeStamp': {'when': '2017-05-25'}, 'gx:V...
# 24          SÜTLÜCE  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 25        BURGAZADA  {'gx:TimeStamp': {'when': '2019-07-02'}, 'gx:V...
# 26         BÜYÜKADA  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 27       HEYBELİADA  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 28        KINALIADA  {'gx:TimeSpan': {'begin': '2020-03-03T07:25:12...
# 29      SEDEF ADASI  {'gx:TimeStamp': {'when': '2020-06-16'}, 'gx:V...
# 30   ANADOLU HİSARI  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 31   ANADOLU KAVAĞI  {'gx:TimeStamp': {'when': '2017-06-14'}, 'gx:V...
# 32       ARNAVUTKÖY  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 33            BEBEK  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 34           BEYKOZ  {'gx:TimeStamp': {'when': '2021-04-30'}, 'gx:V...
# 35       BEYLERBEYİ  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 36        BÜYÜKDERE  {'gx:TimeSpan': {'begin': '2017-04-29T00:00:54...
# 37        ÇENGELKÖY  {'gx:TimeStamp': {'when': '2017-06-14'}, 'gx:V...
# 38          ÇUBUKLU  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 39          EMİRGAN  {'gx:TimeStamp': {'when': '2018-03-30'}, 'gx:V...
# 40  ÇUBUKLU ARABALI  {'gx:TimeStamp': {'when': '2020-06-16'}, 'gx:V...
# 41          İSTİNYE  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 42         KANDİLLİ  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 43          KANLICA  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 44        KUZGUNCUK  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 45          KÜÇÜKSU  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 46          ORTAKÖY  {'gx:TimeStamp': {'when': '2017-06-14'}, 'gx:V...
# 47           POYRAZ  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 48        PAŞABAHÇE  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 49    RUMELİ KAVAĞI  {'gx:TimeStamp': {'when': '2014-03-18'}, 'gx:V...
# 50          SARIYER  {'gx:TimeStamp': {'when': '2018-03-30'}, 'gx:V...
# 51          YENİKÖY  {'gx:TimeStamp': {'when': '2017-06-14'}, 'gx:V...
# 52  ÇUBUKLU ARABALI                                                NaN
# 53  İSTİNYE ARABALI  {'gx:TimeStamp': {'when': '2020-06-16'}, 'gx:V...
#
#             styleUrl                                              Point  \
# 0       #msn_marina8  {'gx:drawOrder': '1', 'coordinates': '29.12942...
# 1       #msn_marina8  {'gx:drawOrder': '1', 'coordinates': '28.98235...
# 2    #msn_marina0201  {'gx:drawOrder': '1', 'coordinates': '29.00734...
# 3    #msn_marina0201  {'gx:drawOrder': '1', 'coordinates': '29.00558...
# 4       #msn_marina9  {'gx:drawOrder': '1', 'coordinates': '29.09401...
# 5       #msn_marina5  {'gx:drawOrder': '1', 'coordinates': '28.97621...
# 6    #msn_marina0201  {'gx:drawOrder': '1', 'coordinates': '28.97515...
# 7   #msn_marina10000  {'gx:drawOrder': '1', 'coordinates': '28.97406...
# 8   #msn_marina10000  {'gx:drawOrder': '1', 'coordinates': '28.97300...
# 9      #msn_marina21  {'gx:drawOrder': '1', 'coordinates': '29.01794...
# 10    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '28.99370...
# 11     #msn_marina22  {'gx:drawOrder': '1', 'coordinates': '29.02165...
# 12     #msn_marina22  {'gx:drawOrder': '1', 'coordinates': '29.02300...
# 13     #msn_marina20  {'gx:drawOrder': '1', 'coordinates': '28.97677...
# 14      #msn_marina5  {'gx:drawOrder': '1', 'coordinates': '28.97514...
# 15    #msn_marina500  {'gx:drawOrder': '1', 'coordinates': '29.02509...
# 16     #msn_marina20  {'gx:drawOrder': '1', 'coordinates': '29.01518...
# 17    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '28.94481...
# 18    #msn_marina001  {'gx:drawOrder': '1', 'coordinates': '28.94917...
# 19     #msn_marina23  {'gx:drawOrder': '1', 'coordinates': '28.96897...
# 20     #msn_marina02  {'gx:drawOrder': '1', 'coordinates': '28.93781...
# 21    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '28.95262...
# 22    #msn_marina001  {'gx:drawOrder': '1', 'coordinates': '28.94910...
# 23    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '28.96627...
# 24    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '28.94077...
# 25      #msn_marina9  {'gx:drawOrder': '1', 'coordinates': '29.07038...
# 26     #msn_marina10  {'gx:drawOrder': '1', 'coordinates': '29.12829...
# 27     #msn_marina10  {'gx:drawOrder': '1', 'coordinates': '29.10155...
# 28      #msn_marina9  {'gx:drawOrder': '1', 'coordinates': '29.05553...
# 29     #msn_marina00  {'gx:drawOrder': '1', 'coordinates': '29.14193...
# 30    #msn_marina021  {'gx:drawOrder': '1', 'coordinates': '29.06666...
# 31    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.08815...
# 32    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.04335...
# 33    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.04431...
# 34    #msn_marina022  {'gx:drawOrder': '1', 'coordinates': '29.09032...
# 35    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.04459...
# 36    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.04621...
# 37    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.05164...
# 38    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.08042...
# 39     #msn_marina70  {'gx:drawOrder': '1', 'coordinates': '29.05613...
# 40      #msn_marina0  {'gx:drawOrder': '1', 'coordinates': '29.08274...
# 41    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.06106...
# 42    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.05819...
# 43    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.06533...
# 44    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.02963...
# 45    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.06492...
# 46    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.02552...
# 47      #msn_marina6  {'gx:drawOrder': '1', 'coordinates': '29.13079...
# 48    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.09320...
# 49    #msn_marina023  {'gx:drawOrder': '1', 'coordinates': '29.07500...
# 50     #msn_marina70  {'gx:drawOrder': '1', 'coordinates': '29.05722...
# 51      #msn_marina5  {'gx:drawOrder': '1', 'coordinates': '29.07103...
# 52    #msn_marina101  {'gx:drawOrder': '1', 'coordinates': '29.08312...
# 53    #msn_marina101  {'gx:drawOrder': '1', 'coordinates': '29.05678...
#
#                                                Camera
# 0                                                 NaN
# 1   {'gx:TimeStamp': {'when': '2020-08-25'}, 'gx:V...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   {'gx:TimeStamp': {'when': '2014-07-10'}, 'gx:V...
# 6   {'gx:TimeStamp': {'when': '2014-07-10'}, 'gx:V...
# 7   {'gx:TimeStamp': {'when': '2014-07-10'}, 'gx:V...
# 8   {'gx:TimeStamp': {'when': '2014-07-10'}, 'gx:V...
# 9   {'gx:TimeStamp': {'when': '2017-06-14'}, 'gx:V...
# 10  {'gx:TimeStamp': {'when': '2019-03-09'}, 'gx:V...
# 11  {'gx:TimeStamp': {'when': '2014-07-10'}, 'gx:V...
# 12  {'gx:TimeStamp': {'when': '2014-07-10'}, 'gx:V...
# 13  {'gx:TimeSpan': {'begin': '2019-11-19T12:29:44...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52  {'gx:TimeStamp': {'when': '2019-04-06'}, 'gx:V...
# 53                                                NaN

# %%
[x for x in df]
df['LookAt']=df['LookAt'].fillna(0)
lenght = len(df)
for i in range(lenght):
    if df['LookAt'][i] == 0 :
        df['LookAt'][i] = df['Camera'][i]

# %% [markdown]
# After combining the placemarks I realized that the longitudes and latitudes are not in one column.Unfortunately, I can't pull the data as they are not in a single column. Therefore I combined the two columns. To be able to do this I set the Nan fields to 0.

# %%
Longitude = []
Latitude = []
for i in range(lenght):
    Longitude.append(df['LookAt'][i]['longitude'])
    Latitude.append(df['LookAt'][i]['latitude'])
df.insert(1, "Longitudes",Longitude)
df.insert(2, "Latitudes",Latitude)

# %% [markdown]
# The question asked me for the longitudes and latitudes of the sea stations so I defined two arrays to hold these fields from the dataframe.
# Then i added these arrays to dataframe.

# %%
del df['Camera']
del df['styleUrl']
del df['Point']
del df['LookAt']

# %% [markdown]
# Finally, delete  the unnecessary columns.

# %%
df
# Out:
#                name         Longitudes          Latitudes
# 0           MALTEPE  29.13060758098593  40.91681013544846
# 1          AHIRKAPI  28.98289668101853  41.00314456999032
# 2        BEŞİKTAŞ-1  29.00778819900819  41.04116198628195
# 3        BEŞİKTAŞ-2   29.0055048939288  41.04065414312002
# 4          BOSTANCI  29.09425745312653  40.95173395654253
# 5         EMİNÖNÜ-1  28.97621869809887  41.01495987953694
# 6         EMİNÖNÜ-2  28.97621869809887  41.01495987953694
# 7         EMİNÖNÜ-3  28.97495985342729  41.01488637107048
# 8         EMİNÖNÜ-4  28.97495985342729  41.01488637107048
# 9        HAYDARPAŞA  29.01810215560077  40.99577360085738
# 10          KABATAŞ  28.99325211289065  41.03138737936629
# 11        KADIKÖY-1  29.02211572735011  40.99098891945888
# 12        KADIKÖY-2  29.02378422054707  40.99126123485841
# 13          KARAKÖY  28.97590906576235  41.02205353005713
# 14        KARAKÖY-2  28.97517820592657  41.02151363263756
# 15             MODA  29.02468630924241  40.97875652067077
# 16          ÜSKÜDAR  29.01517043640954  41.02727798596923
# 17       AYVANSARAY  28.94481397672518  41.04102545236506
# 18            BALAT   28.9489827381236  41.03490189638919
# 19    EMİNÖNÜ HALİÇ  28.97000636016617   41.0211343157203
# 20      EYÜP SULTAN  28.93772446962244  41.04757324587808
# 21            FENER  28.95264940277138  41.03107257160582
# 22           HASKÖY  28.94926476460193  41.04051288073612
# 23        KASIMPAŞA  28.96666648551811  41.03131436574518
# 24          SÜTLÜCE  28.94069218673084  41.04721583521061
# 25        BURGAZADA   29.0708695046941  40.88083696839017
# 26         BÜYÜKADA  29.12813034722439  40.87475134443311
# 27       HEYBELİADA  29.10184455874158  40.87685067073806
# 28        KINALIADA  29.05567810817001  40.91075322405018
# 29      SEDEF ADASI  29.14222132336318  40.85281828131863
# 30   ANADOLU HİSARI  29.06650927746919  41.08327321020175
# 31   ANADOLU KAVAĞI  29.08815820188919  41.17339973246317
# 32       ARNAVUTKÖY  29.04379430703303  41.06747056088449
# 33            BEBEK  29.04447234160673  41.07648766882446
# 34           BEYKOZ  29.09031673327758  41.13457017659933
# 35       BEYLERBEYİ  29.04450797208214  41.04512989629014
# 36        BÜYÜKDERE  29.04606613041452  41.16100728674086
# 37        ÇENGELKÖY  29.05140942518369  41.05105361549738
# 38          ÇUBUKLU  29.08036763314571  41.10806590474426
# 39          EMİRGAN  29.05601828940763  41.10234427582056
# 40  ÇUBUKLU ARABALI  29.08336994355603  41.10843976537936
# 41          İSTİNYE  29.06149478160335  41.11355271194248
# 42         KANDİLLİ  29.05871912597904  41.07519403293655
# 43          KANLICA  29.06514485591157  41.10057261365996
# 44        KUZGUNCUK  29.02959157330829  41.03754893466842
# 45          KÜÇÜKSU  29.06556097427824  41.07998007417348
# 46          ORTAKÖY  29.02592863087842  41.04749608425514
# 47           POYRAZ  29.13087554026528  41.20647961479241
# 48        PAŞABAHÇE  29.09328437602442  41.11792570430826
# 49    RUMELİ KAVAĞI   29.0748362250914  41.18247621378024
# 50          SARIYER  29.05750082659019  41.16629742338651
# 51          YENİKÖY  29.07097570910133  41.12167635650226
# 52  ÇUBUKLU ARABALI  29.08385836099203  41.10772556533772
# 53  İSTİNYE ARABALI  29.05709828076876  41.11325361060186

# %% [markdown]
# # Question 2
#
# For this question we are going to use Istanbul Municipality data at [this link](https://data.ibb.gov.tr/dataset/sehir-hatlari-sefer-sayilari). Data contains Istanbul Deniz Isletmeleri route information.
#
# 1. Understand what the data is for, what it records, what it contains. Explain it in broad strokes.
# 2. Extract the data about the number of trips between stations.
# 2. Calculate the total number of trips in 2020,
# 3. Calculate the total number of trips in 2021,
# 4. Which is the busiest station in 2020 and 2021?
#
# For these questions you must extract the specific data you need from the raw data. Let me be very clear: I am not interested in the numerical answer, I'd like to see your data extraction and calculation explicitly. I need to see your code with which you extract the data, see the data frame where you record the extracted data, and the code where you group and calculate the required results.

# %% [markdown]
# # create and analyze the data (2020)

# %%
with urlopen("https://data.ibb.gov.tr/dataset/4be0d5f6-62de-4a24-a6a5-038009cde39f/resource/f1f95d5d-fa2f-479d-9d50-85ca1d604c1e/download/2020-yl-ehir-hatlar-sefer-saylar.csv") as url:
    data_2020 = pd.read_csv(url,encoding='latin-1')
data_2020
# Out:
#                       YIL;GÜZERGAH;TOPLAM SEFER ADETÝ
# 0                      2020;BEÞÝKTAÞ - KADIKÖY;26.879
# 1                2020;KADIKÖY - KARAKÖY - BEÞÝKTAÞ;13
# 2                       2020;EMÝNÖNÜ - ÜSKÜDAR;28.441
# 3              2020;ÜSKÜDAR - KARAKÖY - EMÝNÖNÜ;8.737
# 4                       2020;KADIKÖY - EMÝNÖNÜ;18.408
# 5                       2020;KADIKÖY - KARAKÖY;25.658
# 6    2020;KABATAÞ - KADIKÖY - ADALAR - BOSTANCI;5.879
# 7                        2020;ÝSTANBUL - ADALAR;4.542
# 8             2020;KADIKÖY - KARAKÖY - EMÝNÖNÜ;11.156
# 9   2020;BOÐAZ GÝDÝÞ GELÝÞ (EMÝNÖNÜ - BEÞÝKTAÞ  -K...
# 10  2020;BOÐAZ GÝDÝÞ GELÝÞ (EMÝNÖNÜ - BEÞÝKTAÞ - O...
# 11          2020;ÇENGELKÖY - BEÞÝKTAÞ - EMÝNÖNÜ;1.056
# 12  2020;ÜSKÜDAR - KARAKÖY - KASIMPAÞA - FENER - B...
# 13          2020;KADIKÖY - EMÝRGAN (LALE SEFERLERÝ);0
# 14        2020;BOSTANCI - BÜYÜKADA - HEYBELÝADA;1.154
# 15                     2020;HEYBELÝADA - BÜYÜKADA;434
# 16                       2020;BOSTANCI - ADALAR;3.022
# 17                     2020;BÜYÜKADA - BOSTANCI;1.182
# 18               2020;BÜYÜKADA - KINALIADA (RÝNG);379
# 19  2020;BEYKOZ - MUHTELÝF ÝSK. - BEÞÝKTAÞ - EMÝNÖ...
# 20          2020;BEYKOZ - MUHTELÝF ÝSK. - EMÝNÖNÜ;559
# 21        2020;A.HÝSARI - MUHTELÝF ÝSK. - EMÝNÖNÜ;562
# 22  2020;ÇENGELKÖY - BEYLERBEYÝ - BEÞÝKTAÞ - EMÝNÖ...
# 23          2020;A.KAVAÐI - R.KAVAÐI - SARIYER;11.005
# 24   2020;ÇENGELKÖY - BEBEK - KANLICA - ÝSTÝNYE;4.487
# 25           2020;KABATAÞ - KÜÇÜK SU - BEÞÝKTAÞ;1.691
# 26  2020;SARIYER - MUHTELÝF BOÐAZ - EMÝNÖNÜ (SARIY...
# 27         2020;BEYKOZ - MUHTELÝF BOÐAZ - ÜSKÜDAR;557
# 28                      2020;KÜÇÜK SU - ÝSTÝNYE;3.925
# 29                       2020;ADALAR - BEÞÝKTAÞ;4.001
# 30                      2020;BÜYÜKADA - SEDEF ADASI;0
# 31    2020;KADIKÖY - BEÞÝKTAÞ - ÝSTÝNYE - SARIYER;559
# 32  2020;A.KAVAÐI - BEYKOZ - PAÞABAHÇE - ÇUBUKLU -...
# 33  2020;RUMELÝ KAVAÐI - SARIYER - ÝSTÝNYE - ARNAV...
# 34            2020;BOSTANCI - KARAKÖY - KABATAÞ;2.781

# %% [markdown]
# We use another encoding because there are characters in the data that are not suitable for utf8

# %%
data_2020[['yıl', 'güzergah', 'toplam sefer adedi']]=data_2020['YIL;GÜZERGAH;TOPLAM SEFER ADETÝ'].str.split(';', expand=True)
del data_2020['YIL;GÜZERGAH;TOPLAM SEFER ADETÝ']

# %% [markdown]
# We divide the fields in the data according to the year, route and total number of trips.

# %%
data_2020['güzergah'] = data_2020['güzergah'].str.replace('Þ','Ş')
data_2020['güzergah'] = data_2020['güzergah'].str.replace('Ý','İ')
data_2020['güzergah'] = data_2020['güzergah'].str.replace('Ð','Ğ')

# %% [markdown]
# I'm replacing some letters with the letters they should be to make it look neater

# %% [markdown]
# # find the total number of trips

# %%
data_2020.dtypes
# Out:
# yıl                   object
# güzergah              object
# toplam sefer adedi    object
# dtype: object

# %%
data_2020['toplam sefer adedi'] = data_2020['toplam sefer adedi'].str.replace('.','' ,regex=True)

# %% [markdown]
# In order to find the total number of trips made in 2020, I needed to collect all the trips, but the data in this column was kept as an object. I removed the dots from the numbers to convert this data into integers.

# %%
data_2020['toplam sefer adedi'] = data_2020['toplam sefer adedi'].astype(int)
data_2020
# Out:
#      yıl                                           güzergah  \
# 0   2020                                 BEŞİKTAŞ - KADIKÖY
# 1   2020                       KADIKÖY - KARAKÖY - BEŞİKTAŞ
# 2   2020                                  EMİNÖNÜ - ÜSKÜDAR
# 3   2020                        ÜSKÜDAR - KARAKÖY - EMİNÖNÜ
# 4   2020                                  KADIKÖY - EMİNÖNÜ
# 5   2020                                  KADIKÖY - KARAKÖY
# 6   2020              KABATAŞ - KADIKÖY - ADALAR - BOSTANCI
# 7   2020                                  İSTANBUL - ADALAR
# 8   2020                        KADIKÖY - KARAKÖY - EMİNÖNÜ
# 9   2020  BOĞAZ GİDİŞ GELİŞ (EMİNÖNÜ - BEŞİKTAŞ  -KUZGUN...
# 10  2020  BOĞAZ GİDİŞ GELİŞ (EMİNÖNÜ - BEŞİKTAŞ - ORTAKÖ...
# 11  2020                     ÇENGELKÖY - BEŞİKTAŞ - EMİNÖNÜ
# 12  2020  ÜSKÜDAR - KARAKÖY - KASIMPAŞA - FENER - BALAT ...
# 13  2020                 KADIKÖY - EMİRGAN (LALE SEFERLERİ)
# 14  2020                   BOSTANCI - BÜYÜKADA - HEYBELİADA
# 15  2020                              HEYBELİADA - BÜYÜKADA
# 16  2020                                  BOSTANCI - ADALAR
# 17  2020                                BÜYÜKADA - BOSTANCI
# 18  2020                        BÜYÜKADA - KINALIADA (RİNG)
# 19  2020        BEYKOZ - MUHTELİF İSK. - BEŞİKTAŞ - EMİNÖNÜ
# 20  2020                   BEYKOZ - MUHTELİF İSK. - EMİNÖNÜ
# 21  2020                 A.HİSARI - MUHTELİF İSK. - EMİNÖNÜ
# 22  2020        ÇENGELKÖY - BEYLERBEYİ - BEŞİKTAŞ - EMİNÖNÜ
# 23  2020                      A.KAVAĞI - R.KAVAĞI - SARIYER
# 24  2020              ÇENGELKÖY - BEBEK - KANLICA - İSTİNYE
# 25  2020                      KABATAŞ - KÜÇÜK SU - BEŞİKTAŞ
# 26  2020  SARIYER - MUHTELİF BOĞAZ - EMİNÖNÜ (SARIYER - ...
# 27  2020                  BEYKOZ - MUHTELİF BOĞAZ - ÜSKÜDAR
# 28  2020                                 KÜÇÜK SU - İSTİNYE
# 29  2020                                  ADALAR - BEŞİKTAŞ
# 30  2020                             BÜYÜKADA - SEDEF ADASI
# 31  2020             KADIKÖY - BEŞİKTAŞ - İSTİNYE - SARIYER
# 32  2020  A.KAVAĞI - BEYKOZ - PAŞABAHÇE - ÇUBUKLU - KANL...
# 33  2020  RUMELİ KAVAĞI - SARIYER - İSTİNYE - ARNAVUTKÖY...
# 34  2020                       BOSTANCI - KARAKÖY - KABATAŞ
#
#     toplam sefer adedi
# 0                26879
# 1                   13
# 2                28441
# 3                 8737
# 4                18408
# 5                25658
# 6                 5879
# 7                 4542
# 8                11156
# 9                  523
# 10                 613
# 11                1056
# 12               10549
# 13                   0
# 14                1154
# 15                 434
# 16                3022
# 17                1182
# 18                 379
# 19                 669
# 20                 559
# 21                 562
# 22                1970
# 23               11005
# 24                4487
# 25                1691
# 26                 795
# 27                 557
# 28                3925
# 29                4001
# 30                   0
# 31                 559
# 32                4490
# 33                6993
# 34                2781

# %% [markdown]
# * Changing the necessary columns type as integer

# %%
data_2020['toplam sefer adedi'].sum()
# Out:
# 193669

# %% [markdown]
# Result is the total number of trips in 2020.

# %% [markdown]
# # create and analyze the data (2021)

# %%
with urlopen("https://data.ibb.gov.tr/dataset/4be0d5f6-62de-4a24-a6a5-038009cde39f/resource/d2c7e4c3-fd09-4952-8a8e-776e3accf91d/download/2021-yl-ehir-hatlar-sefer-saylar.csv") as url:
    data_2021 = pd.read_csv(url,encoding='latin-1')

# %%
data_2021[['yıl', 'güzergah', 'toplam sefer adedi']]=data_2021['Yil;Guzergah;Toplam Sefer Adeti'].str.split(';', expand=True)
del data_2021['Yil;Guzergah;Toplam Sefer Adeti']
data_2021['güzergah'] = data_2021['güzergah'].str.replace('Þ','Ş')
data_2021['güzergah'] = data_2021['güzergah'].str.replace('Ý','İ')
data_2021['güzergah'] = data_2021['güzergah'].str.replace('Ð','Ğ')

# %% [markdown]
# *While creating the data, I applied the same solutions as the previous data.*

# %% [markdown]
# # find the total number of trips

# %%
data_2021.dtypes
# Out:
# yıl                   object
# güzergah              object
# toplam sefer adedi    object
# dtype: object

# %%
data_2021['toplam sefer adedi'] = data_2021['toplam sefer adedi'].str.replace('.','' ,regex=True)
data_2021=data_2021[data_2021['yıl'].str.contains("2021")==True]

# %% [markdown]
# We can't convert to integers because of null values. so we drop all rows which year value is not 2021.

# %%
data_2021['toplam sefer adedi'] = data_2021['toplam sefer adedi'].astype(int)
data_2021
# Out:
#      yıl                                           güzergah  \
# 0   2021                                  BEŞİKTAŞ-KADIKÖY
# 1   2021                                    EMİNÖNÜ-ÜSKÜDAR
# 2   2021                                    EMİNÖNÜ-KADIKÖY
# 3   2021  EMİNÖNÜ-BEŞİKTAŞ-KUZGUNCUK-BEYLERBEYİ-ÇENGELKÖ...
# 4   2021  EMİNÖNÜ-BEŞİKTAŞ-ORTAKÖY-EMİRGAN-PAŞABAHÇE-BEY...
# 5   2021                        ÇENGELKÖY-BEŞİKTAŞ-EMİNÖNÜ
# 6   2021                                    KADIKÖY-KARAKÖY
# 7   2021                            KADIKÖY-KARAKÖY-EMİNÖNÜ
# 8   2021                             KABATAŞ-KADIKÖY-ADALAR
# 9   2021                      BOSTANCI- BÜYÜKADA-HEYBELİADA
# 10  2021                               HEYBELİ ADA-BÜYÜKADA
# 11  2021                          ÜSKÜDAR- KARAKÖY- EMİNÖNÜ
# 12  2021                   BOSTANCI- ADALAR-KADIKÖY-KABATAŞ
# 13  2021                 BOSTANCI- ADALAR- BOSTANCI (RİNG)
# 14  2021  BOSTANCI- KINALIADA-BURGAZADA-HEYBELİADA-BÜYÜKADA
# 15  2021                        KADIKÖY- KARAKÖY- BEŞİKTAŞ
# 16  2021  ÜSKÜDAR-KARAKÖY-KASIMPAŞA-FENER-BALAT-HASKÖY-A...
# 17  2021                           KABATAŞ-BEŞİKTAŞ-KÜÇÜKSU
# 18  2021                                   İSTİNYE-KÜÇÜKSU
# 19  2021                   KADIKÖY-BEŞİKTAŞ-İSTİNYE-SARIYER
# 20  2021                ANADOLUKAVAĞI-RUMELİKAVAĞI-SARIYER
# 21  2021  ÇENGELKÖY- ARNAVUTKÖY-BEBEK- KANDİLLİ- ANADOLU...
# 22  2021               BEBEK-ANADOLU HİSARI-KANLICA-EMİRGAN
# 23  2021  ANADOLU HİSARI- KANDİLLİ-ÇENGELKÖY-BEŞİKTAŞ-EM...
# 24  2021  BEYKOZ -PAŞABAHÇE-KANLICA-ANADOLU HİSARI-KÜÇÜK...
# 25  2021  SARIYER -İSTİNYE-EMİRGAN-BEYLERBEYİ-KUZGUNCUK-...
# 26  2021  BEYKOZ-PAŞABAHÇE-ÇUBUKLU-ANADOLU HİSARI-ÇENGEL...
# 27  2021  BEYKOZ -PAŞABAHÇE-ÇUBUKLU-İSTİNYE-KANLICA-ANAD...
# 28  2021                         ÇENGELKÖY-BEŞİKTAŞ-EMİNÖNÜ
# 29  2021              ÇENGELKÖY-BEYLERBEYİ-BEŞİKTAŞ-EMİNÖNÜ
# 30  2021  EMİNÖNÜ-BEŞİKTAŞ-ARNAVUTKÖY-BEBEK-EMİRGAN-İSTİ...
# 31  2021  ÜSKÜDAR-BEYLERBEYİ-ÇENGELKÖY-ANADOLU HİSARI-KA...
# 32  2021                           BOSTANCI-KARAKÖY-KABATAŞ
# 33  2021                                    ADALAR-BEŞİKTAŞ
# 34  2021                                BÜYÜKADA-SEDEFADASI
# 35  2021                                EMİNÖNÜ- BEYLERBEYİ
# 36  2021           BEYLERBEYİ- KUZGUNCUK- BEŞİKTAŞ- EMİNÖNÜ
# 37  2021                                     SARIYER-BEYKOZ
#
#     toplam sefer adedi
# 0                23658
# 1                23854
# 2                18298
# 3                  497
# 4                  545
# 5                  433
# 6                 6168
# 7                18304
# 8                 7046
# 9                  940
# 10                 364
# 11                8995
# 12                2534
# 13                2891
# 14                 154
# 15                 201
# 16                9106
# 17                1486
# 18                3466
# 19                 494
# 20               10483
# 21                3499
# 22                 969
# 23                 496
# 24                 496
# 25                 726
# 26                 594
# 27                 496
# 28                 496
# 29                1239
# 30                7548
# 31                4989
# 32                2378
# 33                3262
# 34                 389
# 35                 249
# 36                 248
# 37                9891

# %%
data_2021['toplam sefer adedi'].sum()
# Out:
# 177882

# %% [markdown]
# Result is the total number of trips in 2021.

# %%
data_split_2021 =data_2021['güzergah'].str.split('-', expand=True)
data_split_2021
# Out:
#                 0               1                  2               3   \
# 0         BEŞİKTAŞ        KADIKÖY                None            None
# 1          EMİNÖNÜ         ÜSKÜDAR               None            None
# 2          EMİNÖNÜ         KADIKÖY               None            None
# 3          EMİNÖNÜ        BEŞİKTAŞ          KUZGUNCUK      BEYLERBEYİ
# 4          EMİNÖNÜ        BEŞİKTAŞ            ORTAKÖY         EMİRGAN
# 5        ÇENGELKÖY        BEŞİKTAŞ           EMİNÖNÜ             None
# 6          KADIKÖY         KARAKÖY               None            None
# 7          KADIKÖY         KARAKÖY            EMİNÖNÜ            None
# 8          KABATAŞ         KADIKÖY             ADALAR            None
# 9         BOSTANCI        BÜYÜKADA         HEYBELİADA            None
# 10     HEYBELİ ADA        BÜYÜKADA               None            None
# 11         ÜSKÜDAR         KARAKÖY            EMİNÖNÜ            None
# 12        BOSTANCI          ADALAR            KADIKÖY         KABATAŞ
# 13        BOSTANCI          ADALAR   BOSTANCI (RİNG)             None
# 14        BOSTANCI       KINALIADA          BURGAZADA      HEYBELİADA
# 15         KADIKÖY         KARAKÖY          BEŞİKTAŞ             None
# 16         ÜSKÜDAR         KARAKÖY          KASIMPAŞA           FENER
# 17         KABATAŞ        BEŞİKTAŞ            KÜÇÜKSU            None
# 18         İSTİNYE        KÜÇÜKSU                None            None
# 19         KADIKÖY        BEŞİKTAŞ            İSTİNYE         SARIYER
# 20   ANADOLUKAVAĞI    RUMELİKAVAĞI           SARIYER             None
# 21       ÇENGELKÖY      ARNAVUTKÖY              BEBEK        KANDİLLİ
# 22           BEBEK  ANADOLU HİSARI            KANLICA         EMİRGAN
# 23  ANADOLU HİSARI        KANDİLLİ          ÇENGELKÖY        BEŞİKTAŞ
# 24         BEYKOZ        PAŞABAHÇE            KANLICA  ANADOLU HİSARI
# 25        SARIYER          İSTİNYE            EMİRGAN      BEYLERBEYİ
# 26          BEYKOZ       PAŞABAHÇE            ÇUBUKLU  ANADOLU HİSARI
# 27         BEYKOZ        PAŞABAHÇE            ÇUBUKLU         İSTİNYE
# 28       ÇENGELKÖY        BEŞİKTAŞ            EMİNÖNÜ            None
# 29       ÇENGELKÖY      BEYLERBEYİ           BEŞİKTAŞ         EMİNÖNÜ
# 30         EMİNÖNÜ        BEŞİKTAŞ         ARNAVUTKÖY           BEBEK
# 31         ÜSKÜDAR      BEYLERBEYİ          ÇENGELKÖY  ANADOLU HİSARI
# 32        BOSTANCI         KARAKÖY            KABATAŞ            None
# 33          ADALAR        BEŞİKTAŞ               None            None
# 34        BÜYÜKADA      SEDEFADASI               None            None
# 35         EMİNÖNÜ      BEYLERBEYİ               None            None
# 36      BEYLERBEYİ       KUZGUNCUK           BEŞİKTAŞ         EMİNÖNÜ
# 37         SARIYER          BEYKOZ               None            None
#
#                  4               5           6         7              8   \
# 0              None            None        None      None           None
# 1              None            None        None      None           None
# 2              None            None        None      None           None
# 3         ÇENGELKÖY      ARNAVUTKÖY        None      None           None
# 4         PAŞABAHÇE         BEYKOZ         None      None           None
# 5              None            None        None      None           None
# 6              None            None        None      None           None
# 7              None            None        None      None           None
# 8              None            None        None      None           None
# 9              None            None        None      None           None
# 10             None            None        None      None           None
# 11             None            None        None      None           None
# 12             None            None        None      None           None
# 13             None            None        None      None           None
# 14         BÜYÜKADA            None        None      None           None
# 15             None            None        None      None           None
# 16            BALAT          HASKÖY  AYVANSARAY   SÜTLÜCE           EYÜP
# 17             None            None        None      None           None
# 18             None            None        None      None           None
# 19             None            None        None      None           None
# 20             None            None        None      None           None
# 21   ANADOLU HİSARI         KANLICA     EMİRGAN   İSTİNYE           None
# 22             None            None        None      None           None
# 23          EMİNÖNÜ            None        None      None           None
# 24          KÜÇÜKSU         ÜSKÜDAR     KABATAŞ      None           None
# 25        KUZGUNCUK        BEŞİKTAŞ    KABATAŞ    EMİNÖNÜ           None
# 26        ÇENGELKÖY      BEYLERBEYİ   KUZGUNCUK  BEŞİKTAŞ       EMİNÖNÜ
# 27          KANLICA  ANADOLU HİSARI    KANDİLLİ     BEBEK     ARNAVUTKÖY
# 28             None            None        None      None           None
# 29             None            None        None      None           None
# 30          EMİRGAN         İSTİNYE   BÜYÜKDERE   SARIYER  RUMELİ KAVAĞI
# 31         KANLIC A         ÇUBUKLU   PAŞABAHÇE    BEYKOZ  ANADOLUKAVAĞI
# 32             None            None        None      None           None
# 33             None            None        None      None           None
# 34             None            None        None      None           None
# 35             None            None        None      None           None
# 36             None            None        None      None           None
# 37             None            None        None      None           None
#
#          9         10        11
# 0      None      None      None
# 1      None      None      None
# 2      None      None      None
# 3      None      None      None
# 4      None      None      None
# 5      None      None      None
# 6      None      None      None
# 7      None      None      None
# 8      None      None      None
# 9      None      None      None
# 10     None      None      None
# 11     None      None      None
# 12     None      None      None
# 13     None      None      None
# 14     None      None      None
# 15     None      None      None
# 16     None      None      None
# 17     None      None      None
# 18     None      None      None
# 19     None      None      None
# 20     None      None      None
# 21     None      None      None
# 22     None      None      None
# 23     None      None      None
# 24     None      None      None
# 25     None      None      None
# 26     None      None      None
# 27  ORTAKÖY  BEŞİKTAŞ   EMİNÖNÜ
# 28     None      None      None
# 29     None      None      None
# 30     None      None      None
# 31     None      None      None
# 32     None      None      None
# 33     None      None      None
# 34     None      None      None
# 35     None      None      None
# 36     None      None      None
# 37     None      None      None

# %% [markdown]
# * we are splitting route's stations as columns to be able to calculate.

# %%
column_num = data_split_2021.shape[1]-1

# %%
data_split_2021[12] = data_2021['toplam sefer adedi']
data_split_2021
# Out:
#                 0               1                  2               3   \
# 0         BEŞİKTAŞ        KADIKÖY                None            None
# 1          EMİNÖNÜ         ÜSKÜDAR               None            None
# 2          EMİNÖNÜ         KADIKÖY               None            None
# 3          EMİNÖNÜ        BEŞİKTAŞ          KUZGUNCUK      BEYLERBEYİ
# 4          EMİNÖNÜ        BEŞİKTAŞ            ORTAKÖY         EMİRGAN
# 5        ÇENGELKÖY        BEŞİKTAŞ           EMİNÖNÜ             None
# 6          KADIKÖY         KARAKÖY               None            None
# 7          KADIKÖY         KARAKÖY            EMİNÖNÜ            None
# 8          KABATAŞ         KADIKÖY             ADALAR            None
# 9         BOSTANCI        BÜYÜKADA         HEYBELİADA            None
# 10     HEYBELİ ADA        BÜYÜKADA               None            None
# 11         ÜSKÜDAR         KARAKÖY            EMİNÖNÜ            None
# 12        BOSTANCI          ADALAR            KADIKÖY         KABATAŞ
# 13        BOSTANCI          ADALAR   BOSTANCI (RİNG)             None
# 14        BOSTANCI       KINALIADA          BURGAZADA      HEYBELİADA
# 15         KADIKÖY         KARAKÖY          BEŞİKTAŞ             None
# 16         ÜSKÜDAR         KARAKÖY          KASIMPAŞA           FENER
# 17         KABATAŞ        BEŞİKTAŞ            KÜÇÜKSU            None
# 18         İSTİNYE        KÜÇÜKSU                None            None
# 19         KADIKÖY        BEŞİKTAŞ            İSTİNYE         SARIYER
# 20   ANADOLUKAVAĞI    RUMELİKAVAĞI           SARIYER             None
# 21       ÇENGELKÖY      ARNAVUTKÖY              BEBEK        KANDİLLİ
# 22           BEBEK  ANADOLU HİSARI            KANLICA         EMİRGAN
# 23  ANADOLU HİSARI        KANDİLLİ          ÇENGELKÖY        BEŞİKTAŞ
# 24         BEYKOZ        PAŞABAHÇE            KANLICA  ANADOLU HİSARI
# 25        SARIYER          İSTİNYE            EMİRGAN      BEYLERBEYİ
# 26          BEYKOZ       PAŞABAHÇE            ÇUBUKLU  ANADOLU HİSARI
# 27         BEYKOZ        PAŞABAHÇE            ÇUBUKLU         İSTİNYE
# 28       ÇENGELKÖY        BEŞİKTAŞ            EMİNÖNÜ            None
# 29       ÇENGELKÖY      BEYLERBEYİ           BEŞİKTAŞ         EMİNÖNÜ
# 30         EMİNÖNÜ        BEŞİKTAŞ         ARNAVUTKÖY           BEBEK
# 31         ÜSKÜDAR      BEYLERBEYİ          ÇENGELKÖY  ANADOLU HİSARI
# 32        BOSTANCI         KARAKÖY            KABATAŞ            None
# 33          ADALAR        BEŞİKTAŞ               None            None
# 34        BÜYÜKADA      SEDEFADASI               None            None
# 35         EMİNÖNÜ      BEYLERBEYİ               None            None
# 36      BEYLERBEYİ       KUZGUNCUK           BEŞİKTAŞ         EMİNÖNÜ
# 37         SARIYER          BEYKOZ               None            None
#
#                  4               5           6         7              8   \
# 0              None            None        None      None           None
# 1              None            None        None      None           None
# 2              None            None        None      None           None
# 3         ÇENGELKÖY      ARNAVUTKÖY        None      None           None
# 4         PAŞABAHÇE         BEYKOZ         None      None           None
# 5              None            None        None      None           None
# 6              None            None        None      None           None
# 7              None            None        None      None           None
# 8              None            None        None      None           None
# 9              None            None        None      None           None
# 10             None            None        None      None           None
# 11             None            None        None      None           None
# 12             None            None        None      None           None
# 13             None            None        None      None           None
# 14         BÜYÜKADA            None        None      None           None
# 15             None            None        None      None           None
# 16            BALAT          HASKÖY  AYVANSARAY   SÜTLÜCE           EYÜP
# 17             None            None        None      None           None
# 18             None            None        None      None           None
# 19             None            None        None      None           None
# 20             None            None        None      None           None
# 21   ANADOLU HİSARI         KANLICA     EMİRGAN   İSTİNYE           None
# 22             None            None        None      None           None
# 23          EMİNÖNÜ            None        None      None           None
# 24          KÜÇÜKSU         ÜSKÜDAR     KABATAŞ      None           None
# 25        KUZGUNCUK        BEŞİKTAŞ    KABATAŞ    EMİNÖNÜ           None
# 26        ÇENGELKÖY      BEYLERBEYİ   KUZGUNCUK  BEŞİKTAŞ       EMİNÖNÜ
# 27          KANLICA  ANADOLU HİSARI    KANDİLLİ     BEBEK     ARNAVUTKÖY
# 28             None            None        None      None           None
# 29             None            None        None      None           None
# 30          EMİRGAN         İSTİNYE   BÜYÜKDERE   SARIYER  RUMELİ KAVAĞI
# 31         KANLIC A         ÇUBUKLU   PAŞABAHÇE    BEYKOZ  ANADOLUKAVAĞI
# 32             None            None        None      None           None
# 33             None            None        None      None           None
# 34             None            None        None      None           None
# 35             None            None        None      None           None
# 36             None            None        None      None           None
# 37             None            None        None      None           None
#
#          9         10        11     12
# 0      None      None      None  23658
# 1      None      None      None  23854
# 2      None      None      None  18298
# 3      None      None      None    497
# 4      None      None      None    545
# 5      None      None      None    433
# 6      None      None      None   6168
# 7      None      None      None  18304
# 8      None      None      None   7046
# 9      None      None      None    940
# 10     None      None      None    364
# 11     None      None      None   8995
# 12     None      None      None   2534
# 13     None      None      None   2891
# 14     None      None      None    154
# 15     None      None      None    201
# 16     None      None      None   9106
# 17     None      None      None   1486
# 18     None      None      None   3466
# 19     None      None      None    494
# 20     None      None      None  10483
# 21     None      None      None   3499
# 22     None      None      None    969
# 23     None      None      None    496
# 24     None      None      None    496
# 25     None      None      None    726
# 26     None      None      None    594
# 27  ORTAKÖY  BEŞİKTAŞ   EMİNÖNÜ    496
# 28     None      None      None    496
# 29     None      None      None   1239
# 30     None      None      None   7548
# 31     None      None      None   4989
# 32     None      None      None   2378
# 33     None      None      None   3262
# 34     None      None      None    389
# 35     None      None      None    249
# 36     None      None      None    248
# 37     None      None      None   9891

# %% [markdown]
# * Adding *toplam seferi adeti* as last column of the stations dataframe

# %%
new_split_2021 = pd.DataFrame(columns=['istasyon adı','yolcu sayısı'])
df_split = pd.DataFrame(columns=['istasyon adı','yolcu sayısı'])
for i in range(column_num):
    new_split_2021['istasyon adı'] = data_split_2021[i]
    new_split_2021['yolcu sayısı'] = data_split_2021[12]
    df_split = pd.concat([df_split, new_split_2021], ignore_index=True)

# %% [markdown]
# * taking *istasyon adı* and *yolcu sayısı* values and describing as a new data frame for every column then concating them together.
# * so we will have a new df which all stations stands by itself with it's *yolcu sayısı*

# %%
df_split
# Out:
#     istasyon adı yolcu sayısı
# 0       BEŞİKTAŞ        23658
# 1        EMİNÖNÜ        23854
# 2        EMİNÖNÜ        18298
# 3        EMİNÖNÜ          497
# 4        EMİNÖNÜ          545
# ..           ...          ...
# 413         None         3262
# 414         None          389
# 415         None          249
# 416         None          248
# 417         None         9891
#
# [418 rows x 2 columns]

# %%
df_unique_st=df_split['istasyon adı'].unique()

# %%
e=0
passenger_list=[]
for j in df_unique_st:
    for i in range(len(df_split)):
        if df_split['istasyon adı'][i]==j:
            e+=df_split['yolcu sayısı'][i]
        
    passenger_list.append(e)
    e=0

# %%
result_df =pd.DataFrame({'istasyon adı':df_unique_st , 'toplam yolcu sayısı':passenger_list})

# %% [markdown]
# * So now we have all the unique stations names as a list and all the summed passenger numbers by all stations.
# * Now we will use both to create a new dataframe

# %%
result_df
# Out:
#      istasyon adı  toplam yolcu sayısı
# 0        BEŞİKTAŞ                41970
# 1         EMİNÖNÜ                72252
# 2       ÇENGELKÖY                12243
# 3         KADIKÖY                53045
# 4         KABATAŞ                13940
# ..            ...                  ...
# 61        SÜTLÜCE                 9106
# 62        İSTİNYE                 3499
# 63           EYÜP                 9106
# 64       EMİNÖNÜ                   594
# 65  RUMELİ KAVAĞI                 7548
#
# [66 rows x 2 columns]

# %% [markdown]
# # Question 3
#
# Using a different [dataset](https://data.ibb.gov.tr/dataset/istanbul-deniz-iskeleleri-yolcu-sayilari) again from Istanbul Municipality on Istanbul Deniz Isletmeleri:
#
# 1. Understand what the data is for, what it records, what it contains. Explain it in broad strokes.
# 2. Find out the busiest station in the years 2020 and 2021,
# 3. Repeat the same calculation monthly: find the busiest stations for each month.
# 4. Does your calculation of busiest stations agree with the calculation you made in Question #2? Explain.

# %%
with urlopen("https://data.ibb.gov.tr/dataset/20f33ff0-1ab3-4378-9998-486e28242f48/resource/6fbdd928-8c37-43a4-8e6a-ba0fa7f767fb/download/istanbul-deniz-iskeleleri-yolcu-saylar.csv") as url:
    data = pd.read_csv(url,encoding='latin-1')

# %% [markdown]
# We use another encoding again because there are characters in the data that are not suitable for utf8

# %%
data[['yıl', 'ay','otorite adı', 'istasyon adı', 'yolcu sayısı']]=data['Yil;Ay;Otorite Adi;Istasyon Adi;Yolcu Sayisi'].str.split(';', expand=True)

# %% [markdown]
# Correcting the column names and separating them by *;* to have a clear result

# %%
del data['Yil;Ay;Otorite Adi;Istasyon Adi;Yolcu Sayisi']

# %%
data.yıl.unique()
# Out:
# array(['2021'], dtype=object)

# %% [markdown]
# We don't have any 2020 values in this data.

# %%
for i in range(len(data)):
    data['istasyon adı'][i]=data['istasyon adı'][i].upper()

# %% [markdown]
# We have a very bad data and have to clean it.
# first we make them all uppercase to avoid differences.

# %%
data['istasyon adı']= data['istasyon adı'].str.replace('Þ','Ş')
data['istasyon adı']= data['istasyon adı'].str.replace('Ü','U')
data['istasyon adı']= data['istasyon adı'].str.replace('Ö','O')
data['istasyon adı']= data['istasyon adı'].str.replace('İ','I')
data['istasyon adı']= data['istasyon adı'].str.replace('Ý','I')
data['istasyon adı']= data['istasyon adı'].str.replace('Ð','G')
data['istasyon adı']= data['istasyon adı'].str.replace('Ğ','G')

# %% [markdown]
# And to have a that all stations have only one name (nothing like ÇUBUKLU - cubuklu) we are making some corrections.

# %%
data['istasyon adı']= data['istasyon adı'].str.replace('Ş','S')

# %%
data=data.sort_values(by='istasyon adı')

# %%
data['yolcu sayısı']=data['yolcu sayısı'].astype(int)

# %%
df_ist=data['istasyon adı'].unique()

# %% [markdown]
# having all unique station names in a list.

# %%
data
# Out:
#       yıl  ay                                   otorite adı     istasyon adı  \
# 595  2021  11         ÝBB Toplu Ulaþým Hizmetleri Müdürlüðü   ANADOLU HISARI
# 444  2021   9         ÝBB Toplu Ulaþým Hizmetleri Müdürlüðü   ANADOLU HISARI
# 76   2021   4         ÝBB Toplu Ulaþým Hizmetleri Müdürlüðü   ANADOLU HISARI
# 520  2021  10         ÝBB Toplu Ulaþým Hizmetleri Müdürlüðü   ANADOLU HISARI
# 218  2021   6         ÝBB Toplu Ulaþým Hizmetleri Müdürlüðü   ANADOLU HISARI
# ..    ...  ..                                           ...              ...
# 643  2021  11  ÝSTANBUL ÞEHÝR HATLARI TUR. SAN. VE TÝC. AÞ.  ÇUBUKLU ARABALI
# 267  2021   6  ÝSTANBUL ÞEHÝR HATLARI TUR. SAN. VE TÝC. AÞ.  ÇUBUKLU ARABALI
# 194  2021   5  ÝSTANBUL ÞEHÝR HATLARI TUR. SAN. VE TÝC. AÞ.  ÇUBUKLU ARABALI
# 54   2021   3  ÝSTANBUL ÞEHÝR HATLARI TUR. SAN. VE TÝC. AÞ.  ÇUBUKLU ARABALI
# 570  2021  10  ÝSTANBUL ÞEHÝR HATLARI TUR. SAN. VE TÝC. AÞ.  ÇUBUKLU ARABALI
#
#      yolcu sayısı
# 595          3032
# 444          8566
# 76           3690
# 520          9311
# 218          5693
# ..            ...
# 643          7848
# 267         18642
# 194          9404
# 54           4263
# 570         23583
#
# [661 rows x 5 columns]

# %%
d=0
acc=[]
for j in df_ist:
    for i in range(len(data)):
        if data['istasyon adı'][i]==j:
            d+=data['yolcu sayısı'][i]
        
    acc.append(d)
    d=0

# %% [markdown]
# iterating over sorted data frame to find same named stations and adding their *yolcu sayi*'s together

# %%
df=pd.DataFrame({'istasyon adı':df_ist , 'toplam yolcu sayısı':acc})

# %% [markdown]
# merging station names and passenger counts together.

# %%
for i in range(len(df)):
    if df['toplam yolcu sayısı'][i]==df['toplam yolcu sayısı'].max():
        print("the busiest station is" ,df['istasyon adı'][i] , ":" ,df['toplam yolcu sayısı'][i] )
# Out:
# the busiest station is USKUDAR : 6651307

# %%
df
# Out:
#              istasyon adı  toplam yolcu sayısı
# 0          ANADOLU HISARI                48588
# 1          ANADOLU KAVAGI                68503
# 2              ARNAVUTKOY               107144
# 3              AYVANSARAY                13239
# 4                   BALAT                33544
# 5                BARBAROS              1119982
# 6                   BEBEK                53590
# 7                BESIKTAS              4242605
# 8                  BEYKOZ               225292
# 9              BEYLERBEYI                32303
# 10               BOSTANCI               964468
# 11              BURGAZADA               342541
# 12               BUYUKADA              1350678
# 13              CENGELKOY               181186
# 14                CUBUKLU                 4231
# 15                EMINONU              1246545
# 16           EMINONU BOAZ               532875
# 17  EMINONU KADIKOY HATTI              1434552
# 18  EMINONU USKUDAR HATTI              1729972
# 19                EMIRGAN                73133
# 20              ESKIHISAR               124068
# 21                   EYUP               127544
# 22                  FENER                49758
# 23                  HAREM               274039
# 24                 HASKOY                60571
# 25             HEYBELIADA               516898
# 26                ISTINYE               229271
# 27                KABATAS                15578
# 28                KADIKOY                   19
# 29          KADIKOY BALON               769907
# 30           KADIKOY ESKI              1791385
# 31           KADIKOY YENI              1723265
# 32      KADIKOY ÇAYIRBASI              1544819
# 33               KANDILLI                20377
# 34                KANLICA                29598
# 35                KARAKOY              2356375
# 36                 KARTAL               368331
# 37              KASIMPASA               126049
# 38              KINALIADA               490363
# 39                KUCUKSU                35383
# 40              KUZGUNCUK                 9123
# 41                ORTAKOY               121568
# 42              PASABAHCE                22646
# 43           RUMELIKAVAGI                15665
# 44                SARIYER               156215
# 45           SIRKECIHAREM               270034
# 46                SUTLUCE                22932
# 47               TOPCULAR               121859
# 48                USKUDAR              6651307
# 49           YENI KABATAS               996420
# 50               YENIKAPI                  728
# 51                YENIKOY               180464
# 52        ÇUBUKLU ARABALI               134500

# %%
data['ay']=data['ay'].astype(int)

# %% [markdown]
# To do the same thing for months first of all to be able to make calculations we change 'ay' columns type as integer

# %%
month=data.sort_values(by='ay')

# %%
ay=month['ay'].unique()

# %%
d=0
for i in ay:
    data_ay= month.loc[month['ay'] == i]
    ist_ay=data_ay.d=0

df = pd.DataFrame(columns=['ay','istasyon adı','yolcu sayısı'])
for k in month['ay'].unique():
    for j in df_ist:
        for  i in range(len(data)):
            if data['istasyon adı'][i]==j:
                if data['ay'][i] == k:
                    d+=data['yolcu sayısı'][i]
        df.loc[len(df.index)] = [k, j, d]            
        d=0
df.drop(0)
# Out:
#      ay     istasyon adı yolcu sayısı
# 1     3   ANADOLU KAVAGI         1230
# 2     3       ARNAVUTKOY         3136
# 3     3       AYVANSARAY          329
# 4     3            BALAT          889
# 5     3         BARBAROS        29500
# ..   ..              ...          ...
# 472  11          USKUDAR       350978
# 473  11     YENI KABATAS        43205
# 474  11         YENIKAPI            6
# 475  11          YENIKOY        10736
# 476  11  ÇUBUKLU ARABALI         7848
#
# [476 rows x 3 columns]

# %% [markdown]
# To matching months with it's station names and passenger counts I made an an algorithm gives as a dataframe we need.

# %%
for i in ay:
    aylik_data = df.loc[df['ay'] == i]
    sorted_yolcu=aylik_data.sort_values(by='yolcu sayısı', ascending=False)
    yolcu=sorted_yolcu.iloc[0]
    print(yolcu)
# Out:
# ay                    3
# istasyon adı    USKUDAR
# yolcu sayısı     178944
# Name: 48, dtype: object
# ay                    4
# istasyon adı    USKUDAR
# yolcu sayısı     472875
# Name: 101, dtype: object
# ay                    5
# istasyon adı    USKUDAR
# yolcu sayısı     370665
# Name: 154, dtype: object
# ay                    6
# istasyon adı    USKUDAR
# yolcu sayısı     830520
# Name: 207, dtype: object
# ay                    7
# istasyon adı    USKUDAR
# yolcu sayısı    1120694
# Name: 260, dtype: object
# ay                    8
# istasyon adı    USKUDAR
# yolcu sayısı    1081644
# Name: 313, dtype: object
# ay                    9
# istasyon adı    USKUDAR
# yolcu sayısı    1048105
# Name: 366, dtype: object
# ay                   10
# istasyon adı    USKUDAR
# yolcu sayısı    1196882
# Name: 419, dtype: object
# ay                   11
# istasyon adı    USKUDAR
# yolcu sayısı     350978
# Name: 472, dtype: object

# %% [markdown]
# With this last for block we calculated busiest station for every month and it's Üsküdar same result I found in Question 2 and that's logical.
